# %%
import numpy as np
import pandas as pd
import pprint
eps = np.finfo(float).eps
from numpy import log2 as log

# %%
training_data = pd.read_csv("..//Data/Labelled.csv")
training_data = training_data[["Operator","Network Type","In Out Travelling","State Name","label"]]

# %%
training_data
# Out:
#      Operator Network Type In Out Travelling      State Name       label
# 0      Airtel           2G            Indoor  Andhra Pradesh     Average
# 1      Airtel           2G            Indoor           Assam   Very Good
# 2      Airtel           2G            Indoor           Bihar     Average
# 3      Airtel           2G            Indoor           Delhi        Poor
# 4      Airtel           2G            Indoor         Gujarat   Excellent
# ..        ...          ...               ...             ...         ...
# 987  Vodafone           4G        Travelling      Tamil Nadu   Excellent
# 988  Vodafone           4G        Travelling       Telangana   Excellent
# 989  Vodafone           4G        Travelling   Uttar Pradesh     Average
# 990  Vodafone           4G        Travelling     Uttarakhand  Inadequate
# 991  Vodafone           4G        Travelling     West Bengal   Very Good
#
# [992 rows x 5 columns]

# %%
def find_entropy(df):
    columns = df.keys()[-1]   #To make the code generic, changing target variable class name
    entropy = 0
    values = df[columns].unique()
    for value in values:
        fraction = df[columns].value_counts()[value]/len(df[columns])
        entropy += -fraction*np.log2(fraction)
    return entropy
  

def find_entropy_attribute(df,attribute):
    column = df.keys()[-1]   #To make the code generic, changing target variable class name
    target_variables = df[column].unique()  #This gives all 'Yes' and 'No'
    variables = df[attribute].unique()    #This gives different features in that attribute (like 'Hot','Cold' in Temperature)
    entropy2 = 0
    for variable in variables:
        entropy = 0
        for target_variable in target_variables:
            num = len(df[attribute][df[attribute]==variable][df[column] ==target_variable])
            den = len(df[attribute][df[attribute]==variable])
            fraction = num/(den+eps)
            entropy += -fraction*log(fraction+eps)
        fraction2 = den/len(df)
        entropy2 += -fraction2*entropy
    return abs(entropy2)


def find_winner(df):
    Entropy_att = []
    IG = []
    for key in df.keys()[:-1]:
#         Entropy_att.append(find_entropy_attribute(df,key))
        IG.append(find_entropy(df)-find_entropy_attribute(df,key))
    return df.keys()[:-1][np.argmax(IG)]
  
def get_subtable(df, node,value):
    return df[df[node] == value].reset_index(drop=True)


def buildTree(df,tree=None): 
    column = df.keys()[-1]   #To make the code generic, changing target variable class name
    
    #Here we build our decision tree

    #Get attribute with maximum information gain
    node = find_winner(df)
    
    #Get distinct value of that attribute e.g Salary is node and Low,Med and High are values
    attValue = np.unique(df[node])
    
    #Create an empty dictionary to create tree    
    if tree is None:                    
        tree={}
        tree[node] = {}
    
   #We make loop to construct a tree by calling this function recursively. 
    #In this we check if the subset is pure and stops if it is pure. 

    for value in attValue:
        
        subtable = get_subtable(df,node,value)
        clValue,counts = np.unique(subtable['label'],return_counts=True)                        
        
        if len(counts)==1:#Checking purity of subset
            tree[node][value] = clValue[0]                                                    
        else:        
            tree[node][value] = buildTree(subtable) #Calling the function recursively 
                   
    return tree

# %%
tree = buildTree(training_data)

# %%
pprint.pprint(tree)
# Out:
# {'State Name': {'Andaman and Nicobar Islands': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                               'Outdoor': {'Operator': {'BSNL': 'Very '
#                                                                                                                                'Good',
#                                                                                                                        'Vodafone': 'Excellent'}},
#                                                                                               'Travelling': 'Very '
#                                                                                                             'Good'}},
#                                                                  '3G': 'Inadequate',
#                                                                  '4G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                               'Outdoor': 'Excellent',
#                                                                                               'Travelling': 'Inadequate'}}}},
#                 'Andhra Pradesh': {'Operator': {'Airtel': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Average',
#                                                                                                              '3G': 'Excellent',
#                                                                                                              '4G': 'Excellent'}},
#                                                                                  'Outdoor': {'Network Type': {'2G': 'Inadequate',
#                                                                                                               '3G': 'Average',
#                                                                                                               '4G': 'Very '
#                                                                                                                     'Good'}},
#                                                                                  'Travelling': {'Network Type': {'2G': 'Inadequate',
#                                                                                                                  '3G': 'Poor',
#                                                                                                                  '4G': 'Inadequate'}}}},
#                                                 'BSNL': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                'Outdoor': {'Network Type': {'2G': 'Average',
#                                                                                                             '3G': 'Poor',
#                                                                                                             '4G': 'Very '
#                                                                                                                   'Good'}},
#                                                                                'Travelling': {'Network Type': {'2G': 'Very '
#                                                                                                                      'Good',
#                                                                                                                '3G': 'Average',
#                                                                                                                '4G': 'Excellent'}}}},
#                                                 'Idea': {'Network Type': {'2G': 'Average',
#                                                                           '3G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                                        'Outdoor': 'Average',
#                                                                                                        'Travelling': 'Very '
#                                                                                                                      'Good'}},
#                                                                           '4G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                                  'Good',
#                                                                                                        'Outdoor': 'Excellent',
#                                                                                                        'Travelling': 'Very '
#                                                                                                                      'Good'}}}},
#                                                 'Other': 'Inadequate',
#                                                 'RJio': 'Excellent',
#                                                 'Tata': {'Network Type': {'2G': 'Inadequate',
#                                                                           '3G': 'Excellent',
#                                                                           '4G': {'In Out Travelling': {'Outdoor': 'Excellent',
#                                                                                                        'Travelling': 'Inadequate'}}}},
#                                                 'Vodafone': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                    'Outdoor': {'Network Type': {'3G': 'Average',
#                                                                                                                 '4G': 'Very '
#                                                                                                                       'Good'}},
#                                                                                    'Travelling': {'Network Type': {'3G': 'Inadequate',
#                                                                                                                    '4G': 'Very '
#                                                                                                                          'Good'}}}}}},
#                 'Assam': {'Operator': {'Airtel': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Very '
#                                                                                                           'Good',
#                                                                                                     '3G': 'Excellent',
#                                                                                                     '4G': 'Very '
#                                                                                                           'Good'}},
#                                                                         'Outdoor': {'Network Type': {'3G': 'Poor',
#                                                                                                      '4G': 'Inadequate'}},
#                                                                         'Travelling': {'Network Type': {'3G': 'Very '
#                                                                                                               'Good',
#                                                                                                         '4G': 'Excellent'}}}},
#                                        'BSNL': {'Network Type': {'2G': 'Excellent',
#                                                                  '3G': 'Inadequate',
#                                                                  '4G': 'Excellent'}},
#                                        'Idea': 'Excellent',
#                                        'Other': 'Excellent',
#                                        'RJio': {'In Out Travelling': {'Indoor': 'Average',
#                                                                       'Outdoor': 'Average',
#                                                                       'Travelling': 'Excellent'}},
#                                        'Vodafone': {'In Out Travelling': {'Indoor': {'Network Type': {'3G': 'Excellent',
#                                                                                                       '4G': 'Very '
#                                                                                                             'Good'}},
#                                                                           'Outdoor': {'Network Type': {'3G': 'Poor',
#                                                                                                        '4G': 'Inadequate'}},
#                                                                           'Travelling': 'Excellent'}}}},
#                 'Bihar': {'Operator': {'Airtel': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Average',
#                                                                                                     '3G': 'Excellent',
#                                                                                                     '4G': 'Excellent'}},
#                                                                         'Outdoor': {'Network Type': {'2G': 'Excellent',
#                                                                                                      '3G': 'Very '
#                                                                                                            'Good',
#                                                                                                      '4G': 'Very '
#                                                                                                            'Good'}},
#                                                                         'Travelling': {'Network Type': {'2G': 'Poor',
#                                                                                                         '3G': 'Very '
#                                                                                                               'Good',
#                                                                                                         '4G': 'Average'}}}},
#                                        'BSNL': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Inadequate',
#                                                                                                   '4G': 'Poor'}},
#                                                                       'Outdoor': {'Network Type': {'2G': 'Poor',
#                                                                                                    '4G': 'Excellent'}},
#                                                                       'Travelling': 'Inadequate'}},
#                                        'Idea': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                               'Outdoor': 'Excellent',
#                                                                                               'Travelling': 'Excellent'}},
#                                                                  '3G': {'In Out Travelling': {'Indoor': 'Poor',
#                                                                                               'Outdoor': 'Inadequate',
#                                                                                               'Travelling': 'Very '
#                                                                                                             'Good'}},
#                                                                  '4G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                         'Good',
#                                                                                               'Outdoor': 'Average',
#                                                                                               'Travelling': 'Excellent'}}}},
#                                        'Other': 'Excellent',
#                                        'RJio': {'In Out Travelling': {'Indoor': 'Average',
#                                                                       'Outdoor': {'Network Type': {'3G': 'Excellent',
#                                                                                                    '4G': 'Very '
#                                                                                                          'Good'}},
#                                                                       'Travelling': 'Very '
#                                                                                     'Good'}},
#                                        'Vodafone': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                           'Outdoor': {'Network Type': {'3G': 'Inadequate',
#                                                                                                        '4G': 'Excellent'}},
#                                                                           'Travelling': {'Network Type': {'3G': 'Very '
#                                                                                                                 'Good',
#                                                                                                           '4G': 'Average'}}}}}},
#                 'Chandigarh': {'Operator': {'Airtel': {'In Out Travelling': {'Indoor': {'Network Type': {'3G': 'Average',
#                                                                                                          '4G': 'Inadequate'}},
#                                                                              'Outdoor': {'Network Type': {'3G': 'Excellent',
#                                                                                                           '4G': 'Very '
#                                                                                                                 'Good'}},
#                                                                              'Travelling': {'Network Type': {'3G': 'Poor',
#                                                                                                              '4G': 'Inadequate'}}}},
#                                             'Idea': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                            'Outdoor': 'Average'}},
#                                             'RJio': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                      'Good',
#                                                                            'Outdoor': 'Excellent',
#                                                                            'Travelling': 'Very '
#                                                                                          'Good'}},
#                                             'Vodafone': {'Network Type': {'2G': 'Inadequate',
#                                                                           '3G': 'Inadequate',
#                                                                           '4G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                                        'Outdoor': 'Poor'}}}}}},
#                 'Chattisgarh': {'Operator': {'Airtel': {'Network Type': {'2G': 'Inadequate',
#                                                                          '3G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                                       'Outdoor': 'Very '
#                                                                                                                  'Good',
#                                                                                                       'Travelling': 'Very '
#                                                                                                                     'Good'}},
#                                                                          '4G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                                 'Good',
#                                                                                                       'Outdoor': 'Excellent',
#                                                                                                       'Travelling': 'Excellent'}}}},
#                                              'BSNL': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                               'Good',
#                                                                                                     'Outdoor': 'Inadequate',
#                                                                                                     'Travelling': 'Inadequate'}},
#                                                                        '3G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                                     'Outdoor': 'Inadequate',
#                                                                                                     'Travelling': 'Average'}},
#                                                                        '4G': {'In Out Travelling': {'Indoor': 'Poor',
#                                                                                                     'Outdoor': 'Average',
#                                                                                                     'Travelling': 'Excellent'}}}},
#                                              'Idea': {'Network Type': {'2G': 'Excellent',
#                                                                        '3G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                               'Good',
#                                                                                                     'Outdoor': 'Very '
#                                                                                                                'Good',
#                                                                                                     'Travelling': 'Excellent'}},
#                                                                        '4G': 'Excellent'}},
#                                              'RJio': 'Excellent',
#                                              'Tata': {'In Out Travelling': {'Indoor': 'Average',
#                                                                             'Outdoor': 'Inadequate',
#                                                                             'Travelling': 'Excellent'}},
#                                              'Vodafone': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                         'Outdoor': 'Inadequate',
#                                                                                                         'Travelling': 'Excellent'}},
#                                                                            '3G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                         'Outdoor': 'Very '
#                                                                                                                    'Good',
#                                                                                                         'Travelling': 'Excellent'}},
#                                                                            '4G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                                   'Good',
#                                                                                                         'Outdoor': 'Average',
#                                                                                                         'Travelling': 'Very '
#                                                                                                                       'Good'}}}}}},
#                 'Dadra and Nagar Haveli': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                  'Outdoor': {'Operator': {'RJio': 'Average',
#                                                                                           'Vodafone': {'Network Type': {'3G': 'Excellent',
#                                                                                                                         '4G': 'Inadequate'}}}},
#                                                                  'Travelling': 'Excellent'}},
#                 'Daman and Diu': {'Operator': {'Airtel': 'Excellent',
#                                                'Idea': 'Excellent',
#                                                'RJio': 'Excellent',
#                                                'Vodafone': {'Network Type': {'3G': 'Inadequate',
#                                                                              '4G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                           'Outdoor': 'Inadequate'}}}}}},
#                 'Delhi': {'Operator': {'Airtel': {'In Out Travelling': {'Indoor': 'Poor',
#                                                                         'Outdoor': {'Network Type': {'2G': 'Poor',
#                                                                                                      '3G': 'Poor',
#                                                                                                      '4G': 'Inadequate'}},
#                                                                         'Travelling': {'Network Type': {'2G': 'Inadequate',
#                                                                                                         '3G': 'Average',
#                                                                                                         '4G': 'Very '
#                                                                                                               'Good'}}}},
#                                        'BSNL': {'In Out Travelling': {'Indoor': 'Average',
#                                                                       'Outdoor': 'Inadequate'}},
#                                        'Idea': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                               'Outdoor': 'Poor'}},
#                                                                  '3G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                               'Outdoor': 'Poor',
#                                                                                               'Travelling': 'Poor'}},
#                                                                  '4G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                               'Outdoor': 'Average',
#                                                                                               'Travelling': 'Inadequate'}}}},
#                                        'MTNL': {'Network Type': {'3G': {'In Out Travelling': {'Indoor': 'Poor',
#                                                                                               'Outdoor': 'Inadequate',
#                                                                                               'Travelling': 'Inadequate'}},
#                                                                  '4G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                         'Good',
#                                                                                               'Outdoor': 'Poor',
#                                                                                               'Travelling': 'Very '
#                                                                                                             'Good'}}}},
#                                        'Other': 'Excellent',
#                                        'RJio': {'Network Type': {'2G': 'Inadequate',
#                                                                  '3G': {'In Out Travelling': {'Outdoor': 'Poor',
#                                                                                               'Travelling': 'Excellent'}},
#                                                                  '4G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                               'Outdoor': 'Very '
#                                                                                                          'Good',
#                                                                                               'Travelling': 'Poor'}}}},
#                                        'Vodafone': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                                   'Outdoor': 'Average',
#                                                                                                   'Travelling': 'Inadequate'}},
#                                                                      '3G': {'In Out Travelling': {'Indoor': 'Poor',
#                                                                                                   'Outdoor': 'Very '
#                                                                                                              'Good',
#                                                                                                   'Travelling': 'Average'}},
#                                                                      '4G': 'Average'}}}},
#                 'Goa': {'Operator': {'Airtel': 'Inadequate',
#                                      'Idea': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Excellent',
#                                                                                                 '3G': 'Very '
#                                                                                                       'Good',
#                                                                                                 '4G': 'Excellent'}},
#                                                                     'Outdoor': 'Average',
#                                                                     'Travelling': 'Excellent'}},
#                                      'RJio': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                     'Outdoor': 'Poor',
#                                                                     'Travelling': 'Excellent'}},
#                                      'Vodafone': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                         'Outdoor': {'Network Type': {'2G': 'Poor',
#                                                                                                      '3G': 'Excellent',
#                                                                                                      '4G': 'Very '
#                                                                                                            'Good'}},
#                                                                         'Travelling': 'Excellent'}}}},
#                 'Gujarat': {'Operator': {'Airtel': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                           'Outdoor': 'Very '
#                                                                                      'Good',
#                                                                           'Travelling': {'Network Type': {'2G': 'Very '
#                                                                                                                 'Good',
#                                                                                                           '3G': 'Very '
#                                                                                                                 'Good',
#                                                                                                           '4G': 'Excellent'}}}},
#                                          'BSNL': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Average',
#                                                                                                     '3G': 'Inadequate',
#                                                                                                     '4G': 'Very '
#                                                                                                           'Good'}},
#                                                                         'Outdoor': {'Network Type': {'2G': 'Average',
#                                                                                                      '3G': 'Average',
#                                                                                                      '4G': 'Excellent'}},
#                                                                         'Travelling': 'Very '
#                                                                                       'Good'}},
#                                          'Idea': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Inadequate',
#                                                                                                     '3G': 'Average',
#                                                                                                     '4G': 'Average'}},
#                                                                         'Outdoor': {'Network Type': {'2G': 'Excellent',
#                                                                                                      '3G': 'Very '
#                                                                                                            'Good',
#                                                                                                      '4G': 'Average'}},
#                                                                         'Travelling': {'Network Type': {'2G': 'Very '
#                                                                                                               'Good',
#                                                                                                         '3G': 'Excellent',
#                                                                                                         '4G': 'Excellent'}}}},
#                                          'Other': 'Excellent',
#                                          'RJio': {'In Out Travelling': {'Indoor': 'Average',
#                                                                         'Outdoor': 'Excellent',
#                                                                         'Travelling': 'Excellent'}},
#                                          'Tata': {'In Out Travelling': {'Outdoor': 'Average',
#                                                                         'Travelling': 'Inadequate'}},
#                                          'Telenor': 'Poor',
#                                          'Vodafone': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                       'Good',
#                                                                             'Outdoor': {'Network Type': {'2G': 'Very '
#                                                                                                                'Good',
#                                                                                                          '3G': 'Excellent',
#                                                                                                          '4G': 'Very '
#                                                                                                                'Good'}},
#                                                                             'Travelling': 'Excellent'}}}},
#                 'Haryana': {'Operator': {'Airtel': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                   'Outdoor': 'Inadequate',
#                                                                                                   'Travelling': 'Average'}},
#                                                                      '3G': 'Very '
#                                                                            'Good',
#                                                                      '4G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                   'Outdoor': 'Very '
#                                                                                                              'Good',
#                                                                                                   'Travelling': 'Excellent'}}}},
#                                          'BSNL': {'In Out Travelling': {'Indoor': 'Average',
#                                                                         'Outdoor': 'Excellent',
#                                                                         'Travelling': {'Network Type': {'2G': 'Excellent',
#                                                                                                         '3G': 'Very '
#                                                                                                               'Good',
#                                                                                                         '4G': 'Inadequate'}}}},
#                                          'Idea': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Excellent',
#                                                                                                     '3G': 'Poor',
#                                                                                                     '4G': 'Poor'}},
#                                                                         'Outdoor': 'Inadequate',
#                                                                         'Travelling': {'Network Type': {'2G': 'Poor',
#                                                                                                         '3G': 'Inadequate',
#                                                                                                         '4G': 'Inadequate'}}}},
#                                          'MTNL': {'In Out Travelling': {'Indoor': {'Network Type': {'3G': 'Poor',
#                                                                                                     '4G': 'Very '
#                                                                                                           'Good'}},
#                                                                         'Outdoor': 'Inadequate',
#                                                                         'Travelling': 'Poor'}},
#                                          'Other': 'Excellent',
#                                          'RJio': {'Network Type': {'2G': 'Excellent',
#                                                                    '3G': 'Excellent',
#                                                                    '4G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                                 'Outdoor': 'Average',
#                                                                                                 'Travelling': 'Poor'}}}},
#                                          'Tata': 'Inadequate',
#                                          'Vodafone': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Very '
#                                                                                                               'Good',
#                                                                                                         '3G': 'Poor',
#                                                                                                         '4G': 'Poor'}},
#                                                                             'Outdoor': {'Network Type': {'2G': 'Inadequate',
#                                                                                                          '3G': 'Average',
#                                                                                                          '4G': 'Average'}},
#                                                                             'Travelling': 'Very '
#                                                                                           'Good'}}}},
#                 'Himachal Pradesh': {'In Out Travelling': {'Indoor': {'Operator': {'Airtel': {'Network Type': {'2G': 'Inadequate',
#                                                                                                                '3G': 'Inadequate',
#                                                                                                                '4G': 'Poor'}},
#                                                                                    'BSNL': 'Average',
#                                                                                    'RJio': 'Inadequate',
#                                                                                    'Vodafone': 'Excellent'}},
#                                                            'Outdoor': {'Operator': {'Airtel': {'Network Type': {'2G': 'Very '
#                                                                                                                       'Good',
#                                                                                                                 '3G': 'Average',
#                                                                                                                 '4G': 'Average'}},
#                                                                                     'BSNL': {'Network Type': {'2G': 'Inadequate',
#                                                                                                               '3G': 'Excellent'}},
#                                                                                     'RJio': 'Very '
#                                                                                             'Good',
#                                                                                     'Vodafone': 'Excellent'}},
#                                                            'Travelling': {'Operator': {'Airtel': 'Excellent',
#                                                                                        'BSNL': 'Inadequate',
#                                                                                        'RJio': 'Excellent',
#                                                                                        'Vodafone': 'Excellent'}}}},
#                 'Jharkhand': {'Operator': {'Airtel': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Excellent',
#                                                                                                         '3G': 'Average',
#                                                                                                         '4G': 'Very '
#                                                                                                               'Good'}},
#                                                                             'Outdoor': {'Network Type': {'2G': 'Poor',
#                                                                                                          '3G': 'Inadequate',
#                                                                                                          '4G': 'Poor'}},
#                                                                             'Travelling': {'Network Type': {'2G': 'Inadequate',
#                                                                                                             '3G': 'Inadequate',
#                                                                                                             '4G': 'Average'}}}},
#                                            'BSNL': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                                   'Outdoor': 'Poor',
#                                                                                                   'Travelling': 'Very '
#                                                                                                                 'Good'}},
#                                                                      '3G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                                   'Outdoor': 'Inadequate',
#                                                                                                   'Travelling': 'Average'}},
#                                                                      '4G': 'Excellent'}},
#                                            'Idea': {'Network Type': {'2G': {'In Out Travelling': {'Outdoor': 'Inadequate',
#                                                                                                   'Travelling': 'Excellent'}},
#                                                                      '3G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                   'Outdoor': 'Average',
#                                                                                                   'Travelling': 'Average'}},
#                                                                      '4G': 'Excellent'}},
#                                            'Other': 'Excellent',
#                                            'RJio': 'Excellent',
#                                            'Vodafone': 'Inadequate'}},
#                 'Karnataka': {'Operator': {'Airtel': {'Network Type': {'2G': 'Poor',
#                                                                        '3G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                               'Good',
#                                                                                                     'Outdoor': 'Poor',
#                                                                                                     'Travelling': 'Average'}},
#                                                                        '4G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                               'Good',
#                                                                                                     'Outdoor': 'Very '
#                                                                                                                'Good',
#                                                                                                     'Travelling': 'Average'}}}},
#                                            'BSNL': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                             'Good',
#                                                                                                   'Outdoor': 'Excellent',
#                                                                                                   'Travelling': 'Poor'}},
#                                                                      '3G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                                   'Outdoor': 'Very '
#                                                                                                              'Good',
#                                                                                                   'Travelling': 'Very '
#                                                                                                                 'Good'}},
#                                                                      '4G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                   'Outdoor': 'Average',
#                                                                                                   'Travelling': 'Excellent'}}}},
#                                            'Idea': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Inadequate',
#                                                                                                       '3G': 'Poor',
#                                                                                                       '4G': 'Poor'}},
#                                                                           'Outdoor': 'Inadequate',
#                                                                           'Travelling': {'Network Type': {'3G': 'Very '
#                                                                                                                 'Good',
#                                                                                                           '4G': 'Average'}}}},
#                                            'MTNL': 'Excellent',
#                                            'Other': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                            'Outdoor': 'Poor',
#                                                                            'Travelling': 'Very '
#                                                                                          'Good'}},
#                                            'RJio': {'In Out Travelling': {'Indoor': {'Network Type': {'3G': 'Inadequate',
#                                                                                                       '4G': 'Very '
#                                                                                                             'Good'}},
#                                                                           'Outdoor': {'Network Type': {'3G': 'Very '
#                                                                                                              'Good',
#                                                                                                        '4G': 'Excellent'}},
#                                                                           'Travelling': {'Network Type': {'2G': 'Excellent',
#                                                                                                           '3G': 'Excellent',
#                                                                                                           '4G': 'Very '
# ...
#                                          'Vodafone': 'Excellent'}},
#                 'Uttar Pradesh': {'Operator': {'Airtel': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Poor',
#                                                                                                         'Outdoor': 'Inadequate',
#                                                                                                         'Travelling': 'Inadequate'}},
#                                                                            '3G': 'Average',
#                                                                            '4G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                                   'Good',
#                                                                                                         'Outdoor': 'Average',
#                                                                                                         'Travelling': 'Very '
#                                                                                                                       'Good'}}}},
#                                                'BSNL': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                                 'Good',
#                                                                                                       'Outdoor': 'Excellent',
#                                                                                                       'Travelling': 'Very '
#                                                                                                                     'Good'}},
#                                                                          '3G': 'Very '
#                                                                                'Good',
#                                                                          '4G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                                       'Outdoor': 'Poor',
#                                                                                                       'Travelling': 'Very '
#                                                                                                                     'Good'}}}},
#                                                'Idea': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Poor',
#                                                                                                           '3G': 'Poor',
#                                                                                                           '4G': 'Average'}},
#                                                                               'Outdoor': {'Network Type': {'2G': 'Average',
#                                                                                                            '3G': 'Very '
#                                                                                                                  'Good',
#                                                                                                            '4G': 'Very '
#                                                                                                                  'Good'}},
#                                                                               'Travelling': 'Average'}},
#                                                'MTNL': {'Network Type': {'2G': 'Excellent',
#                                                                          '3G': 'Inadequate',
#                                                                          '4G': 'Inadequate'}},
#                                                'Other': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                'Outdoor': {'Network Type': {'3G': 'Excellent',
#                                                                                                             '4G': 'Average'}},
#                                                                                'Travelling': 'Excellent'}},
#                                                'RJio': {'Network Type': {'2G': 'Excellent',
#                                                                          '3G': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                                       'Outdoor': 'Very '
#                                                                                                                  'Good',
#                                                                                                       'Travelling': 'Very '
#                                                                                                                     'Good'}},
#                                                                          '4G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                                       'Outdoor': 'Very '
#                                                                                                                  'Good',
#                                                                                                       'Travelling': 'Average'}}}},
#                                                'Telenor': 'Inadequate',
#                                                'Vodafone': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Average',
#                                                                                                               '3G': 'Very '
#                                                                                                                     'Good',
#                                                                                                               '4G': 'Very '
#                                                                                                                     'Good'}},
#                                                                                   'Outdoor': {'Network Type': {'2G': 'Poor',
#                                                                                                                '3G': 'Very '
#                                                                                                                      'Good',
#                                                                                                                '4G': 'Very '
#                                                                                                                      'Good'}},
#                                                                                   'Travelling': 'Average'}}}},
#                 'Uttarakhand': {'Operator': {'Airtel': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Inadequate',
#                                                                                                           '3G': 'Inadequate',
#                                                                                                           '4G': 'Average'}},
#                                                                               'Outdoor': {'Network Type': {'2G': 'Inadequate',
#                                                                                                            '3G': 'Inadequate',
#                                                                                                            '4G': 'Poor'}},
#                                                                               'Travelling': {'Network Type': {'2G': 'Poor',
#                                                                                                               '3G': 'Excellent',
#                                                                                                               '4G': 'Excellent'}}}},
#                                              'BSNL': {'Network Type': {'2G': 'Inadequate',
#                                                                        '3G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                                     'Outdoor': 'Inadequate',
#                                                                                                     'Travelling': 'Inadequate'}},
#                                                                        '4G': 'Average'}},
#                                              'Idea': {'In Out Travelling': {'Indoor': {'Network Type': {'2G': 'Inadequate',
#                                                                                                         '3G': 'Poor',
#                                                                                                         '4G': 'Average'}},
#                                                                             'Outdoor': {'Network Type': {'2G': 'Average',
#                                                                                                          '3G': 'Very '
#                                                                                                                'Good',
#                                                                                                          '4G': 'Very '
#                                                                                                                'Good'}},
#                                                                             'Travelling': {'Network Type': {'2G': 'Very '
#                                                                                                                   'Good',
#                                                                                                             '3G': 'Average',
#                                                                                                             '4G': 'Poor'}}}},
#                                              'Other': 'Excellent',
#                                              'RJio': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                       'Good',
#                                                                             'Outdoor': 'Very '
#                                                                                        'Good',
#                                                                             'Travelling': 'Average'}},
#                                              'Telenor': 'Excellent',
#                                              'Vodafone': {'In Out Travelling': {'Indoor': 'Inadequate',
#                                                                                 'Outdoor': {'Network Type': {'3G': 'Excellent',
#                                                                                                              '4G': 'Inadequate'}},
#                                                                                 'Travelling': {'Network Type': {'3G': 'Very '
#                                                                                                                       'Good',
#                                                                                                                 '4G': 'Inadequate'}}}}}},
#                 'West Bengal': {'Operator': {'Airtel': {'Network Type': {'2G': 'Very '
#                                                                                'Good',
#                                                                          '3G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                       'Outdoor': 'Very '
#                                                                                                                  'Good',
#                                                                                                       'Travelling': 'Average'}},
#                                                                          '4G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                       'Outdoor': 'Excellent',
#                                                                                                       'Travelling': 'Very '
#                                                                                                                     'Good'}}}},
#                                              'BSNL': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                                     'Outdoor': 'Inadequate',
#                                                                                                     'Travelling': 'Inadequate'}},
#                                                                        '3G': {'In Out Travelling': {'Indoor': 'Very '
#                                                                                                               'Good',
#                                                                                                     'Outdoor': 'Inadequate',
#                                                                                                     'Travelling': 'Inadequate'}},
#                                                                        '4G': 'Excellent'}},
#                                              'Idea': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                             'Outdoor': 'Excellent',
#                                                                             'Travelling': {'Network Type': {'2G': 'Inadequate',
#                                                                                                             '3G': 'Inadequate',
#                                                                                                             '4G': 'Excellent'}}}},
#                                              'Other': {'In Out Travelling': {'Outdoor': 'Poor',
#                                                                              'Travelling': 'Inadequate'}},
#                                              'RJio': {'Network Type': {'2G': 'Inadequate',
#                                                                        '3G': 'Excellent',
#                                                                        '4G': {'In Out Travelling': {'Indoor': 'Excellent',
#                                                                                                     'Outdoor': 'Very '
#                                                                                                                'Good',
#                                                                                                     'Travelling': 'Excellent'}}}},
#                                              'Tata': 'Inadequate',
#                                              'Vodafone': {'Network Type': {'2G': {'In Out Travelling': {'Indoor': 'Average',
#                                                                                                         'Outdoor': 'Very '
#                                                                                                                    'Good',
#                                                                                                         'Travelling': 'Average'}},
#                                                                            '3G': 'Very '
#                                                                                  'Good',
#                                                                            '4G': 'Very '
#                                                                                  'Good'}}}}}}

# %%
def predict(inst,tree):
    #This function is used to predict for any input variable 
    
    #Recursively we go through the tree that we built earlier

    for nodes in tree.keys():        
        
        value = inst[nodes]
        tree = tree[nodes][value]
        prediction = 0
            
        if type(tree) is dict:
            prediction = predict(inst, tree)
        else:
            prediction = tree
            break;                            
        
    return prediction

# %%
inst = training_data.loc[900]
inst
# Out:
# Operator               Vodafone
# Network Type                 3G
# In Out Travelling    Travelling
# State Name                  Goa
# label                 Excellent
# Name: 900, dtype: object

# %%
prediction = predict(inst, tree)
prediction
# Out:
# 'Excellent'
